# %%
import pandas as pd
pd.read_csv("C:/Users/user/Desktop/portal-teachingdb-master/surveys.csv")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
surveys_df=pd.read_csv("C:/Users/user/Desktop/portal-teachingdb-master/surveys.csv")
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.head(15)
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10         11      7   16  1977        5         DS    F             53.0
# 11         12      7   16  1977        7         DM    M             38.0
# ...

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
site_names=pd.unique(surveys_df['plot_id'])
site_names
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24], dtype=int64)

# %%
len(site_names)
# Out:
# 24

# %%
surveys_df['plot_id'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0         2
# 1         3
# 2         2
# 3         7
# 4         3
#          ..
# 35544    15
# 35545    15
# 35546    10
# 35547     7
# 35548     5
# Name: plot_id, Length: 35549, dtype: int64>

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
surveys_df['weight'].min()
# Out:
# 4.0

# %%
surveys_df['weight'].max()
# Out:
# 280.0

# %%
grouped_data=surveys_df.groupby('sex')

# %%
grouped_data.describe()
# Out:
#     record_id                                                               \
#         count          mean           std  min      25%      50%       75%
# sex
# F     15690.0  18036.412046  10423.089000  3.0  8917.50  18075.5  27250.00
# M     17348.0  17754.835601  10132.203323  1.0  8969.75  17727.5  26454.25
#
#                 month            ... hindfoot_length         weight  \
#          max    count      mean  ...             75%   max    count
# sex                              ...
# F    35547.0  15690.0  6.587253  ...            36.0  64.0  15303.0
# M    35548.0  17348.0  6.396184  ...            36.0  58.0  16879.0
#
#
#           mean        std  min   25%   50%   75%    max
# sex
# F    42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    42.995379  36.184981  4.0  20.0  39.0  49.0  280.0
#
# [2 rows x 56 columns]

# %%
grouped_data.mean()
# Out:
#         record_id     month        day         year    plot_id  \
# sex
# F    18036.412046  6.587253  15.880943  1990.644997  11.440854
# M    17754.835601  6.396184  16.078799  1990.480401  11.098282
#
#      hindfoot_length     weight
# sex
# F          28.836780  42.170555
# M          29.709578  42.995379

# %%
grouped_data3=surveys_df.groupby(['sex','record_id'])
grouped_data3.count()
# Out:
#                month  day  year  plot_id  species_id  hindfoot_length  weight
# sex record_id
# F   3              1    1     1        1           1                1       0
#     7              1    1     1        1           1                0       0
#     9              1    1     1        1           1                1       0
#     10             1    1     1        1           1                1       0
#     11             1    1     1        1           1                1       0
# ...              ...  ...   ...      ...         ...              ...     ...
# M   35525          1    1     1        1           1                1       1
#     35534          1    1     1        1           1                1       1
#     35535          1    1     1        1           1                1       1
#     35539          1    1     1        1           1                1       1
#     35548          1    1     1        1           1                1       1
#
# ...

# %%
grouped_data2 = surveys_df.groupby(['plot_id','sex'])
grouped_data2.mean()
# Out:
#                 record_id     month        day         year  hindfoot_length  \
# plot_id sex
# 1       F    18390.384434  6.597877  15.338443  1990.933962        31.733911
#         M    17197.740639  6.121461  15.905936  1990.091324        34.302770
# 2       F    17714.753608  6.426804  16.288660  1990.449485        30.161220
#         M    18085.458042  6.340035  15.440559  1990.756119        30.353760
# 3       F    19888.783875  6.610302  15.993281  1992.013438        23.774044
#         M    20226.767857  6.277381  16.271429  1992.275000        23.833744
# 4       F    17489.205275  6.447248  15.608945  1990.235092        33.249102
#         M    18493.841748  6.436893  16.303883  1991.000971        34.097959
# 5       F    12280.793169  6.142315  15.722960  1986.485769        28.921844
#         M    12798.426621  6.194539  15.703072  1986.817406        29.694794
# 6       F    19406.503392  6.640434  15.947083  1991.579376        26.981322
# ...

# %%
by_site=surveys_df.groupby(['plot_id','weight'])
print(by_site.describe())
# Out:
#                record_id                                               \
#                    count          mean          std      min      25%
# plot_id weight
# 1       4.0          1.0    218.000000          NaN    218.0    218.0
#         5.0          1.0   7301.000000          NaN   7301.0   7301.0
#         6.0          5.0  13401.200000  9568.661855   4749.0   7071.0
#         7.0         17.0  13024.647059  9900.497058    376.0   3092.0
#         8.0          9.0  23538.333333  7863.208680   5466.0  23507.0
# ...                  ...           ...          ...      ...      ...
# 24      224.0        1.0  35479.000000          NaN  35479.0  35479.0
#         225.0        1.0  35284.000000          NaN  35284.0  35284.0
#         226.0        1.0   5349.000000          NaN   5349.0   5349.0
#         230.0        1.0  14658.000000          NaN  14658.0  14658.0
#         251.0        1.0   4373.000000          NaN   4373.0   4373.0
#
# ...

# %%
species_count=surveys_df.groupby('species_id')['record_id'].count()
print(species_count)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
species_count2=surveys_df.groupby('species_id')['record_id'].count()['DO']
print(species_count2)
# Out:
# 3027

# %%
surveys_df['weight']*2
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 35544      NaN
# 35545      NaN
# 35546     28.0
# 35547    102.0
# 35548      NaN
# Name: weight, Length: 35549, dtype: float64

# %%
# %matplotlib inline
species_count.plot(kind='bar')

# %%
try:
   total_count=surveys_df.groupby('plot_id')['record_id'].nunique()
   total_count.plot(kind='bar')
except AttributeError as e:
    print(e)
except exception as e:
    print(e)

# %%
weight_avg=surveys_df.groupby(['species_id','plot_id'])['weight'].mean()
weight_avg.plot(kind='bar')

# %%
total_gender=surveys_df.groupby('sex')['record_id'].count()
total_gender.plot(kind='bar')

# %%
d = {'one' : pd.Series([1., 2., 3.], index=['a', 'b', 'c']),'two' : pd.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])}
pd.DataFrame(d)
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
my_df = pd.DataFrame(d)
my_df.plot(kind='bar',stacked=True,title="My One/Two",colors=['red','blue'])
# Out:
# D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py:203: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   "'colors' is being deprecated. Please use 'color'"

# %%
my_df = pd.DataFrame(d).unstack()
my_df.plot(kind='bar',stacked=True,title="My One/Two",colors=['red','blue'])
