# %%
# %matplotlib inline
import plotnine as p9

# %%
import pandas as pd
surveys_complete = pd.read_csv("C:/Users/user/Desktop/portal-teachingdb-master/surveys.csv")
surveys_complete = surveys_complete.dropna()

# %%
(p9.ggplot(data=surveys_complete))
# Out:
# <ggplot: (-9223372036842118200)>

# %%
p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
# Out:
# <ggplot: (12661182)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point()
)
# Out:
# <ggplot: (-9223372036842046183)>

# %%
surveys_plot=p9.ggplot(data=surveys_complete,mapping=p9.aes(x='weight',y='hindfoot_length'))
surveys_plot+p9.geom_point(colour='red')
# Out:
# <ggplot: (13901576)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point(alpha=0.1)
)
# Out:
# <ggplot: (14557213)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point(alpha=0.1, color='blue')
)
# Out:
# <ggplot: (13954182)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
)
# Out:
# <ggplot: (-9223372036840874187)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.xlab("Weight (g)")
)
# Out:
# <ggplot: (14551174)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.xlab("Weight (g)")
    + p9.scale_x_log10()
)
# Out:
# <ggplot: (-9223372036838237615)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.xlab("Weight (g)")
    + p9.scale_x_log10()
    + p9.theme_bw()
    + p9.theme(text=p9.element_text(size=16))
)
# Out:
# <ggplot: (12731852)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
    + p9.geom_boxplot()
)
# Out:
# <ggplot: (-9223372036838238783)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
    + p9.geom_jitter(alpha=0.2)
    + p9.geom_boxplot(alpha=0.)
)
# Out:
# <ggplot: (-9223372036835492783)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
    + p9.geom_jitter(alpha=0.2)
    + p9.geom_violin(alpha=0.)
)
# Out:
# D:\Anaconda\lib\site-packages\plotnine\stats\stat.py:311: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   stats = pd.concat(stats, axis=0, ignore_index=True)
# <ggplot: (-9223372036838258239)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='plot_id',
                          fill='sex'))
    + p9.geom_bar()
    + p9.scale_fill_manual(["blue", "orange"])
)
# Out:
# <ggplot: (-9223372036834967250)>

# %%
yearly_counts = surveys_complete.groupby(['year', 'species_id'])['species_id'].count()
yearly_counts
# Out:
# year  species_id
# 1977  DM            181
#       DO             12
#       DS             29
#       OL              1
#       OX              2
#                    ...
# 2002  PP            375
#       RM             20
#       RO              7
#       SF              5
#       SH              9
# Name: species_id, Length: 332, dtype: int64

# %%
yearly_counts = yearly_counts.reset_index(name='counts')
yearly_counts
# Out:
#      year species_id  counts
# 0    1977         DM     181
# 1    1977         DO      12
# 2    1977         DS      29
# 3    1977         OL       1
# 4    1977         OX       2
# ..    ...        ...     ...
# 327  2002         PP     375
# 328  2002         RM      20
# 329  2002         RO       7
# 330  2002         SF       5
# 331  2002         SH       9
#
# [332 rows x 3 columns]

# %%
(p9.ggplot(data=yearly_counts,
           mapping=p9.aes(x='year',
                          y='counts'))
    + p9.geom_line()
)
# Out:
# <ggplot: (-9223372036840833697)>

# %%
(p9.ggplot(data=yearly_counts,
           mapping=p9.aes(x='year',
                          y='counts',
                          color='species_id'))
    + p9.geom_line()
)
# Out:
# <ggplot: (-9223372036840259012)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
)
# Out:
# <ggplot: (13942129)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.facet_wrap("sex")
)
# Out:
# <ggplot: (16550832)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.facet_wrap("plot_id")
)
# Out:
# <ggplot: (17483882)>

# %%
survey_2000 = surveys_complete[surveys_complete["year"].isin([2000, 2001])]

(p9.ggplot(data=survey_2000,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.facet_grid("year ~ sex")
)
# Out:
# <ggplot: (-9223372036832930935)>

# %%
yearly_weight = surveys_complete.groupby(['year','species_id'])['weight'].mean().reset_index()
(p9.ggplot(data=yearly_weight,
           mapping=p9.aes(x='year',
                          y='weight'))
    + p9.geom_line()
    + p9.facet_wrap("species_id")
)
# Out:
# D:\Anaconda\lib\site-packages\plotnine\geoms\geom_path.py:83: PlotnineWarning: geom_path: Each group consist of only one observation. Do you need to adjust the group aesthetic?
#   "group aesthetic?", PlotnineWarning)
# <ggplot: (16692193)>

# %%
yearly_weight = surveys_complete.groupby(['year', 'species_id', 'sex'])['weight'].mean().reset_index()
(p9.ggplot(data=yearly_weight, mapping=p9.aes(x='year', y='weight', color='species_id')) + p9.geom_line() + p9.facet_wrap('sex') )
# Out:
# <ggplot: (14393285)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='factor(year)'))
    + p9.geom_bar()
    
)
# Out:
# <ggplot: (14466140)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='factor(year)'))
    + p9.geom_bar()
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (-9223372036838535508)>

# %%
my_custom_theme = p9.theme(axis_text_x = p9.element_text(color="grey", size=10,
                                                         angle=90, hjust=.5),
                           axis_text_y = p9.element_text(color="grey", size=10))
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='factor(year)'))
    + p9.geom_bar()
    + my_custom_theme
)
# Out:
# <ggplot: (16424719)>

# %%
my_plot = (p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point()
)
my_plot.save('C:/Users/user/Desktop/portal-teachingdb-master/scatterplot.png', width=10, height=10, dpi=300)
# Out:
# D:\Anaconda\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 10 x 10 in image.
#   from_inches(height, units), units), PlotnineWarning)
# D:\Anaconda\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:/Users/user/Desktop/portal-teachingdb-master/scatterplot.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
